# %% [markdown]
# <a href="https://colab.research.google.com/github/gaeun1961/DS_Basic_Analysis_Python/blob/main/03_%EC%99%80%EC%9D%B8_%ED%92%88%EC%A7%88_%EB%93%B1%EA%B8%89_%EC%98%88%EC%B8%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
red_df = pd.read_csv('/content/drive/MyDrive/data/DS_Basic_Analysis_Python/winequality-red.csv', sep=';', header = 0, engine = 'python')
white_df = pd.read_csv('/content/drive/MyDrive/data/DS_Basic_Analysis_Python/winequality-white.csv', sep=';', header = 0, engine = 'python')
red_df.to_csv('/content/drive/MyDrive/data/DS_Basic_Analysis_Python/winequality-red.csv', index = False)
white_df.to_csv('/content/drive/MyDrive/data/DS_Basic_Analysis_Python/winequality-white.csv', index = False)

# %%
#데이터 병합
red_df.head()
#red_df에 저장된 내용을 위에서부터 5개 (0~4번) 행만 출력하여 확인
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
red_df.insert(0,column = 'type', value = 'red')
#이름이 'type'이고 값이 'red'인 열을 만들어 index 0번에 삽입
red_df.head()
# Out:
#   type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  red            7.4              0.70         0.00             1.9
# 1  red            7.8              0.88         0.00             2.6
# 2  red            7.8              0.76         0.04             2.3
# 3  red           11.2              0.28         0.56             1.9
# 4  red            7.4              0.70         0.00             1.9
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality
# 0       0.56      9.4        5
# 1       0.68      9.8        5
# ...

# %%
red_df.shape
#red_df의 현재 크기를 (행의 개수, 열의 개수) 형태로 확인
# Out:
# (1599, 13)

# %%
white_df.head()
#white_df에 저장된 내용을 위에서부터 5개 (0~4번) 행만 출력하여 확인
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
white_df.insert(0,column = 'type', value = 'white')
#이름이 'type'이고 값이 'white'인 열을 만들어 index 0번에 삽입
white_df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
white_df.shape
#white_df의 현재 크기를 (행의 개수, 열의 개수) 형태로 확인
# Out:
# (4898, 13)

# %%
#red_df와 white_df를 하나의 데이터프레임 형식으로 결합
wine = pd.concat([red_df, white_df])
#pd.concat() 함수를 이용해 red_df와 white_df를 결합
wine.shape
# Out:
# (6497, 13)

# %%
wine.head()
# Out:
#   type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  red            7.4              0.70         0.00             1.9
# 1  red            7.8              0.88         0.00             2.6
# 2  red            7.8              0.76         0.04             2.3
# 3  red           11.2              0.28         0.56             1.9
# 4  red            7.4              0.70         0.00             1.9
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality
# 0       0.56      9.4        5
# 1       0.68      9.8        5
# ...

# %%
#데이터 탐색
print(wine.info())
#기본 정보
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6497 entries, 0 to 4897
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6497 non-null   float64
#  2   volatile acidity      6497 non-null   float64
#  3   citric acid           6497 non-null   float64
#  4   residual sugar        6497 non-null   float64
#  5   chlorides             6497 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6497 non-null   float64
#  10  sulphates             6497 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 710.6+ KB
# None

# %%
wine.columns = wine.columns.str.replace(' ', '_')
#전처리. 가독성을 위해 컬럼의 문자열에서 공백을 _로 바꿈
wine.head()
# Out:
#   type  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0  red            7.4              0.70         0.00             1.9
# 1  red            7.8              0.88         0.00             2.6
# 2  red            7.8              0.76         0.04             2.3
# 3  red           11.2              0.28         0.56             1.9
# 4  red            7.4              0.70         0.00             1.9
#
#    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality
# 0       0.56      9.4        5
# 1       0.68      9.8        5
# ...

# %%
wine.describe()
#describe()함수를 사용하여 기술통계 분석
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
sorted(wine.quality.unique())
#wine.quality.unique() 함수를 사용하여 quality 속성값 중에서 유일한 값을 출력
#이를 통해 와인 품질 등급(quality)에 3, 4, 5, 6, 7, 8, 9의 7개 등급이 있음을 확인 가능
# Out:
# [np.int64(3),
#  np.int64(4),
#  np.int64(5),
#  np.int64(6),
#  np.int64(7),
#  np.int64(8),
#  np.int64(9)]

# %%
wine.quality.value_counts()
#quality.value_counts() 함수는 quality 속성값에 대한 빈도수를 보여줌
#6등급인 샘플이 가장 많고 9등급인 샘플이 가장 적음을 알 수 있음
# Out:
# quality
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# Name: count, dtype: int64

# %%
#데이터 모델링
wine.groupby('type')['quality'].describe()
#레드 와인과 화이트 와인을 구분하는 속성인 type을 기준으로 그룹을 나눈 뒤 그룹 안에서 quality 속성을 기준으로 기술 통계
# Out:
#         count      mean       std  min  25%  50%  75%  max
# type
# red    1599.0  5.636023  0.807569  3.0  5.0  6.0  6.0  8.0
# white  4898.0  5.877909  0.885639  3.0  5.0  6.0  6.0  9.0

# %%
wine.groupby('type')['quality'].mean()
#mean()함수로 평균만 구하기
# Out:
# type
# red      5.636023
# white    5.877909
# Name: quality, dtype: float64

# %%
wine.groupby('type')['quality'].std()
#std() 함수로 표준편차만 구하기
# Out:
# type
# red      0.807569
# white    0.885639
# Name: quality, dtype: float64

# %%
wine.groupby('type')['quality'].agg(['mean', 'std'])
#agg() 함수로 mean() 함수와 std() 함수를 묶어서 한 번에 사용하기
# Out:
#            mean       std
# type
# red    5.636023  0.807569
# white  5.877909  0.885639

# %%
#t-검정과 회귀 분석으로 그룹 비교
# !pip install statsmodels
#statsmodels 패키지 설치

# %%
from scipy import stats
from statsmodels.formula.api import ols, glm
#함수 로드
red_wine_quality = wine.loc[wine['type'] == 'red', 'quality']
white_wine_quality = wine.loc[wine['type'] == 'white', 'quality']
#레드/화이트 와인 샘플의 quality 값만 찾아서 각각 red_wine/white_wine에 저장
stats.ttest_ind(red_wine_quality, white_wine_quality, equal_var = False)
#scipy 패키지의 stats.ttest_ind() 함수를 사용하여 t-검정을 하고 두 그룹 간의 차이를 확인
#p-value가 0.05보다 작으면 두 그룹 간의 차이가 있는 것으로 확인
Rformula = 'quality ~ fixed_acidity + volatile_acidity + citric_acid + residual_sugar + chlorides + free_sulfur_dioxide + total_sulfur_dioxide + density + pH + sulphates + alcohol'
#종속 변수 = quality, 독립 변수 = type와 quality를 제외한 11개 속성
#종속 변수 ~~ 독립 변수1 + 독립 변수2 ... + 독립 변수n
regression_result = ols(Rformula, data = wine).fit()
#선형 회귀 모델 중 ols 모델 사용
#statsmodels.formula.api 패키지의 ols() 함수는 첫 번째 인자로 종속 변수와 독립 변수를 구성한 변수를 줌
#두 번째 인자는 실제 사용할 변수값을 가진 데이터프레임 지정
#완성된 선형 회귀 모델은 fit() 함수에 의해 실행되어 regression_result에 저장
regression_result.summary()
#통계값 출력

# Dep.Variable : 종족변수
# Model : 회귀 모델 종류
# Method : 회귀 분석 함수
# Time : 회귀 분석 수행 시간
# No. Observations : 샘플 개수 : 총 표본 수
# Df Residuals : 잔차의 자유도 : 총 표본 수 - 종족 변수 개수 - 독립 변수 개수
# Df Model : 모델의 자유도 : 독립 변수 개수
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                quality   R-squared:                       0.292
# Model:                            OLS   Adj. R-squared:                  0.291
# Method:                 Least Squares   F-statistic:                     243.3
# Date:                Tue, 05 Aug 2025   Prob (F-statistic):               0.00
# Time:                        06:27:47   Log-Likelihood:                -7215.5
# No. Observations:                6497   AIC:                         1.445e+04
# Df Residuals:                    6485   BIC:                         1.454e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
#회귀 분석 모델로 새로운 샘플의 품질 등급 예측
sample1 = wine[wine.columns.difference(['quality', 'type'])]
#wine에서 quality와 type 열은 제외하고 독립 변수만 추출하여 sample1에 저장
sample1 = sample1[0:5][:]
#sample1에 있는 샘플 중 5개 (0번~4번) 샘플만 추출, sample1에 다시 저장하여 예측에 사용할 샘플 제작
sample1_predict = regression_result.predict(sample1)
#샘플 데이터를 regression_result의 예측 함수 predict()에 적용하여 수행한 뒤 결과 예측값을 sample1_predict에 저장
sample1_predict
# Out:
# 0    4.997607
# 1    4.924993
# 2    5.034663
# 3    5.680333
# 4    4.997607
# dtype: float64

# %%
wine[0:5]['quality']
#wine에서 0번부터 4번까지 샘플의 quality값을 출력하여 sample_predict가 맞게 예측되었는지 확인
# Out:
# 0    5
# 1    5
# 2    5
# 3    6
# 4    5
# Name: quality, dtype: int64

# %%
data = {"fixed_acidity":[8.5, 8.1], "volatile_acidity":[0.8, 0.5], "citric_acid":[0.3, 0.4], "residual_sugar":[6.1, 5.8], "chlorides":[0.055, 0.04], "free_sulfur_dioxide":[30.0, 31.0], "total_sulfur_dioxide":[98.0, 99], "density":[0.996, 0.91], "pH":[3.25, 3.01], "sulphates":[0.4, 0.35], "alcohol":[9.0, 0.88]}
#회귀식에 사용한 독립 변수에 대입할 임의의 값을 딕셔너리 형태로 제작
sample2 = pd.DataFrame(data, columns = sample1.columns)
#딕셔너리 형태의 값과 sample1의 열 이름만 뽑아 데이터프레임으로 묶은 sample2 제작
sample2
# Out:
#    alcohol  chlorides  citric_acid  density  fixed_acidity  \
# 0     9.00      0.055          0.3    0.996            8.5
# 1     0.88      0.040          0.4    0.910            8.1
#
#    free_sulfur_dioxide    pH  residual_sugar  sulphates  total_sulfur_dioxide  \
# 0                 30.0  3.25             6.1       0.40                  98.0
# 1                 31.0  3.01             5.8       0.35                  99.0
#
#    volatile_acidity
# 0               0.8
# 1               0.5

# %%
sample2_predict = regression_result.predict(sample2)
#샘플 데이터를 regression)result의 예측 함수 predict()에 적용하여 수행한 뒤 결과 예측값을 sample2_predict에 저장
sample2_predict
# Out:
# 0    4.809094
# 1    7.582129
# dtype: float64

# %%
#결과 시각화
#와인 유형에 따른 품질 등급 히스토그램 그리기
import matplotlib.pyplot as plt
import seaborn as sns
#패키지 로드
sns.set_style('dark')
#히스토그램 차트의 배경색 스타일 지정
sns.histplot(red_wine_quality, stat = 'density', kde = True, color = 'red', label = 'red wine')
sns.histplot(white_wine_quality, stat = 'density', kde = True, label = 'white wine')
#레드/화이트 와인에 대한 histplot 객체 생성
plt.title("quality of Wine Type")
#차트 제목 설정
plt.legend()
#차트 범례 설정
plt.show()

# %%
#부분 회귀 플롯으로 시각화
import statsmodels.api as sm

others = list(set(wine.columns).difference(set(["quality", "fixed_acidity"])))
#부분 회귀에 사용할 독립 변수 fixed_acidity와 종속 변수를 제외한 나머지 변수 이름을 리스트 others로 추출
p, resids = sm.graphics.plot_partregress("quality", "fixed_acidity", others, data = wine, ret_coords = True)
#나머지 변수는 고정하고 fixed_acidity가 종속 변수 quality에 미치는 영향에 부분 회귀를 수행
plt.show()

# %%
fig = plt.figure(figsize = (8, 13))
#차트의 크기 지정
sm.graphics.plot_partregress_grid(regression_result, fig = fig)
#다중 선형 회귀 분석 결과를 가지고 있는 regression_result를 이용해 각 독립 변수의 부분 회귀 플롯을 구함
plt.show()
